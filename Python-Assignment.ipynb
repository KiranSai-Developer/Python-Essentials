# %%
MyList=[1,2,3,4,5]
MyList.append(6)

# %%
MyList
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
MyList.remove(1)

# %%
MyList
# Out:
# [2, 3, 4, 5, 6]

# %%
MyList.pop(3)
MyList
# Out:
# [2, 3, 4, 6]

# %%
MyList.index(6)
MyList
# Out:
# [2, 3, 4, 6]

# %%
index=MyList.index(6)
print("Index of 6:",index)
# Out:
# Index of 6: 3

# %%
MyList.insert(1,2)
MyList
# Out:
# [2, 2, 3, 4, 6]

# %%
count=MyList.count(2)
print("Count of 2 is:",count)
# Out:
# Count of 2 is: 2

# %%
print("The Orginial List is:",MyList)
MyList.reverse()
print("The Reversed List is:",MyList)
# Out:
# The Orginial List is: [2, 2, 3, 4, 6]
# The Reversed List is: [6, 4, 3, 2, 2]

# %%
MyList.remove(2)
MyList
# Out:
# [6, 4, 3, 2]

# %%
MyList.sort()
print("The Sorted List is:",MyList)
# Out:
# The Sorted List is: [2, 3, 4, 6]

# %%
phninfo = {'Name':'Abhay','Phone Name':'Oneplus','Sim':'Jio'}
print("NAME:",phninfo.get('Name'))
print("Cell Phone Name:",phninfo.get('Phone Name'))
# Out:
# NAME: Abhay
# Cell Phone Name: Oneplus

# %%
phninfo.keys()
# Out:
# dict_keys(['Name', 'Phone Name', 'Sim'])

# %%
phninfo.values()
# Out:
# dict_values(['Abhay', 'Oneplus', 'Jio'])

# %%
phninfo.pop('Sim')
# Out:
# 'Jio'

# %%
phninfo
# Out:
# {'Name': 'Abhay', 'Phone Name': 'Oneplus'}

# %%
phninfo['Price']="33000"
phninfo
# Out:
# {'Name': 'Abhay', 'Phone Name': 'Oneplus', 'Price': '33000'}

# %%
del phninfo["Price"]
phninfo
# Out:
# {'Name': 'Abhay', 'Phone Name': 'Oneplus'}

# %%
len(phninfo)
# Out:
# 2
